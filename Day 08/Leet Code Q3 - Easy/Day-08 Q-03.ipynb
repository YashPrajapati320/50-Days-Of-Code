# %% [markdown]
# # Same Tree

# %% [raw]
# Example 1:
#
# Input:     1         1
#           / \       / \
#          2   3     2   3
#
#         [1,2,3],   [1,2,3]
#
# Output: true
#
# Example 2:
#
# Input:     1         1
#           /           \
#          2             2
#
#         [1,2],     [1,null,2]
#
# Output: false
#
# Example 3:
#
# Input:     1         1
#           / \       / \
#          2   1     1   2
#
#         [1,2,1],   [1,1,2]
#
# Output: false

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def isSameTree(self, p: TreeNode, q: TreeNode) -> bool:
        print(p)

# %%
isSameTree(2,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6e4b3dabbec7> in <module>
# ----> 1 isSameTree(2,2)
#
# NameError: name 'isSameTree' is not defined

# %%
from binarytree import Node 
def TreeNode(node,left,right):
    Tree1 = Node(node) 
    Tree1.left = Node(left) 
    Tree1.right = Node(right)

# %%
Tree1 = TreeNode(1,2,3)
Tree2 = TreeNode(1,2,3)
print('Tree1 is {}'.format(Tree1))
print('Tree2 is {}'.format(Tree2))
# Out:
# Tree1 is None
# Tree2 is None

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSameTree(self, p: TreeNode, q: TreeNode) -> bool:
        if p and q:
            return p.val == q.val and self.isSameTree(p.left, q.left) and self.isSameTree(p.right, q.right)
        return p is q
