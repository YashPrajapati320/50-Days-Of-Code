# %%
import numpy as np
from itertools import chain

input = [
  ["5","3",".",".","7",".",".",".","."],
  ["6",".",".","1","9","5",".",".","."],
  [".","9","8",".",".",".",".","6","."],
  ["8",".",".",".","6",".",".",".","3"],
  ["4",".",".","8",".","3",".",".","1"],
  ["7",".",".",".","2",".",".",".","6"],
  [".","6",".",".",".",".","2","8","."],
  [".",".",".","4","1","9",".",".","5"],
  [".",".",".",".","8",".",".","7","9"]
]

original = input

indexes = []

def blockshaped(arr, nrows, ncols):
    arr = np.array(arr)
    h, w = arr.shape
    assert h % nrows == 0, "{} rows is not evenly divisble by {}".format(h, nrows)
    assert w % ncols == 0, "{} cols is not evenly divisble by {}".format(w, ncols)
    threedarray = arr.reshape(h//nrows, nrows, -1, ncols).swapaxes(1,2).reshape(-1, nrows, ncols)
    condition_3_array = []
    for i in threedarray:
        condition_3_array.append(list(chain.from_iterable(i)))
    return condition_3_array            

def rowCheck(input,num):
    print('Step ' + str(num))
    print('Row Check')
    
    for i in range(0,len(input)):
        for j in range(0,len(input)):
            if len(input[i][j]) != 1:
                integer = ''
                for k in input[i][j]:
                    if k not in input[i] :
                        integer += k
                        input[i][j] = integer
    
    #print(input)
    columnCheck(input,num) 
        
def columnCheck(input,num):
    input = list(map(list, zip(*input)))

    print('Column Check')

    for i in range(0,len(input)):
        for j in range(0,len(input)):
            if len(input[i][j]) != 1:
                integer = ''
                for k in input[i][j]:
                    if k not in input[i]:
                        integer += k
                        input[i][j] = integer

    input = list(map(list, zip(*input)))

    #print(input)
    innerMatrixCheck(input,num)

    
def innerMatrixCheck(input,num):    

    print('Inner Matrix Check')        

    temp = blockshaped(input,3,3)
    count = 0
    for i in range(0,len(input)):
        for j in range(0,len(input)):
            if len(input[i][j]) != 1:
                integer = ''
                for k in input[i][j]:
                    if k not in temp[(int(i/3)*3+int(j/3))]:
                        integer += k
                        input[i][j] = integer
    
    #print(input)
    flag = True
    for i in range(0,len(input)):
        for j in range(0,len(input)):
            if len(input[i][j])!=1:
                flag = False
                #print(i,j,flag)
                break
        else:
            continue
        break
    
    print(flag)
    if flag == False:
        rowCheck(input,num+1)
    elif flag == True:          
        return print(input)

for i in range(0,len(input)):
    for j in range(0,len(input)):
        if input[i][j] == '.':
            indexes.append([i,j])
            input[i][j] = '123456789'
            
rowCheck(input,num=1)
#print(result_1)
#result_2 = checkArray(result_1,box,indexes,i=2)
#print(result_2)
#result_3 = checkArray(result_2,box,indexes,i=3)
#print(result_3)
#result_4 = checkArray(result_3,box,indexes,i=4)
#print(result_4)
#result_5 = checkArray(result_4,box,indexes,i=5)
#print(result_5)
# Out:
# Step 1
# Row Check
# Column Check
# Inner Matrix Check
# False
# Step 2
# Row Check
# Column Check
# Inner Matrix Check
# False
# Step 3
# Row Check
# Column Check
# Inner Matrix Check
# False
# Step 4
# Row Check
# Column Check
# Inner Matrix Check
# False
# Step 5
# Row Check
# Column Check
# Inner Matrix Check
# True
# [['5', '3', '4', '6', '7', '8', '9', '1', '2'], ['6', '7', '2', '1', '9', '5', '3', '4', '8'], ['1', '9', '8', '3', '4', '2', '5', '6', '7'], ['8', '5', '9', '7', '6', '1', '4', '2', '3'], ['4', '2', '6', '8', '5', '3', '7', '9', '1'], ['7', '1', '3', '9', '2', '4', '8', '5', '6'], ['9', '6', '1', '5', '3', '7', '2', '8', '4'], ['2', '8', '7', '4', '1', '9', '6', '3', '5'], ['3', '4', '5', '2', '8', '6', '1', '7', '9']]

# %%
Step 1
Row Check
Column Check
Inner Matrix Check
[['5', '3', '124', '26', '7', '2468', '1489', '1249', '248'], ['6', '247', '247', '1', '9', '5', '3478', '234', '2478'], ['12', '9', '8', '23', '34', '24', '13457', '6', '247'], ['8', '125', '1259', '79', '6', '147', '4579', '2459', '3'], ['4', '25', '2569', '8', '5', '3', '579', '259', '1'], ['7', '15', '1359', '9', '2', '14', '4589', '459', '6'], ['139', '6', '134579', '357', '3', '7', '2', '8', '4'], ['23', '278', '237', '4', '1', '9', '36', '3', '5'], ['123', '1245', '12345', '2356', '8', '26', '1346', '7', '9']]
Step 2
Row Check
Column Check
Inner Matrix Check
[['5', '3', '24', '26', '7', '268', '1489', '124', '28'], ['6', '47', '24', '1', '9', '5', '3478', '24', '278'], ['1', '9', '8', '23', '4', '2', '13457', '6', '27'], ['8', '15', '159', '7', '6', '14', '457', '245', '3'], ['4', '2', '69', '8', '5', '3', '7', '9', '1'], ['7', '15', '135', '9', '2', '14', '458', '45', '6'], ['9', '6', '15', '5', '3', '7', '2', '8', '4'], ['2', '8', '7', '4', '1', '9', '6', '3', '5'], ['3', '145', '145', '26', '8', '26', '1', '7', '9']]
Step 3
Row Check
Column Check
Inner Matrix Check
[['5', '3', '24', '6', '7', '68', '489', '124', '28'], ['6', '47', '24', '1', '9', '5', '348', '24', '28'], ['1', '9', '8', '3', '4', '2', '5', '6', '7'], ['8', '15', '59', '7', '6', '14', '4', '25', '3'], ['4', '2', '6', '8', '5', '3', '7', '9', '1'], ['7', '15', '35', '9', '2', '14', '8', '5', '6'], ['9', '6', '1', '5', '3', '7', '2', '8', '4'], ['2', '8', '7', '4', '1', '9', '6', '3', '5'], ['3', '45', '45', '2', '8', '6', '1', '7', '9']]
Step 4
Row Check
Column Check
Inner Matrix Check
[['5', '3', '24', '6', '7', '8', '9', '14', '2'], ['6', '47', '24', '1', '9', '5', '3', '4', '8'], ['1', '9', '8', '3', '4', '2', '5', '6', '7'], ['8', '5', '9', '7', '6', '1', '4', '2', '3'], ['4', '2', '6', '8', '5', '3', '7', '9', '1'], ['7', '1', '3', '9', '2', '4', '8', '5', '6'], ['9', '6', '1', '5', '3', '7', '2', '8', '4'], ['2', '8', '7', '4', '1', '9', '6', '3', '5'], ['3', '4', '5', '2', '8', '6', '1', '7', '9']]
Step 5
Row Check
Column Check
Inner Matrix Check
[['5', '3', '4', '6', '7', '8', '9', '1', '2'], ['6', '7', '2', '1', '9', '5', '3', '4', '8'], ['1', '9', '8', '3', '4', '2', '5', '6', '7'], ['8', '5', '9', '7', '6', '1', '4', '2', '3'], ['4', '2', '6', '8', '5', '3', '7', '9', '1'], ['7', '1', '3', '9', '2', '4', '8', '5', '6'], ['9', '6', '1', '5', '3', '7', '2', '8', '4'], ['2', '8', '7', '4', '1', '9', '6', '3', '5'], ['3', '4', '5', '2', '8', '6', '1', '7', '9']]

# %%
array = []
if '1' in ['12']:
    print('Hello')

# %%
abc = [['5', '3', '1', '2', '7', '8', '9', '1', '8'], ['6', '247', '247', '1', '9', '5', '3478', '234', '2478'], ['12', '9', '8', '23', '34', '24', '13457', '6', '247'], ['8', '125', '1259', '79', '6', '147', '4579', '2459', '3'], ['4', '25', '2569', '8', '5', '3', '579', '259', '1'], ['7', '15', '1359', '9', '2', '14', '4589', '459', '6'], ['139', '6', '134579', '357', '3', '7', '2', '8', '4'], ['23', '278', '237', '4', '1', '9', '36', '3', '5'], ['123', '1245', '12345', '2356', '8', '26', '1346', '7', '9']]

flag = True
for i in range(0,len(abc)):
    for j in range(0,len(abc)):
        if len(abc[i][j])!=1:
            flag = False
            print(i,j,flag)
            break
    else:
        continue
    break

print(flag)
# Out:
# 1 1 False
# False
